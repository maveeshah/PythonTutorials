# %% [markdown]
# # DataFrame Data Structure

# %%
import pandas as pd

# %%
purchase_1 = pd.Series({'Name':'Junior Einstein','Item':'Xiaomi Mi','Cost':'400$'})
purchase_2 = pd.Series({'Name':'Uzair Abid','Item':'Iphone','Cost':'700$'})
purchase_3 = pd.Series({'Name':'Mavee Shah','Item':'Nokia','Cost':'600$'})

df = pd.DataFrame([purchase_1,purchase_2,purchase_3],index=['Shop1','Shop2','Shop3'])
df.head()
# Out:
#                   Name       Item  Cost
# Shop1  Junior Einstein  Xiaomi Mi  400$
# Shop2       Uzair Abid     Iphone  700$
# Shop3       Mavee Shah      Nokia  600$

# %%
print(df['Item'])
print(df.iloc[1])
# Out:
# Shop1    Xiaomi Mi
# Shop2       Iphone
# Shop3        Nokia
# Name: Item, dtype: object
# Name    Uzair Abid
# Item        Iphone
# Cost          700$
# Name: Shop2, dtype: object

# %%
df['Cost'].max()
# Out:
# '700$'

# %%
df.loc[:,['Name','Cost']]
# Out:
#                   Name  Cost
# Shop1  Junior Einstein  400$
# Shop2       Uzair Abid  700$
# Shop3       Mavee Shah  600$

# %%
df['Location'] = 'Islamabad'

# %%
df
# Out:
#                   Name       Item  Cost   Location
# Shop1  Junior Einstein  Xiaomi Mi  400$  Islamabad
# Shop2       Uzair Abid     Iphone  700$  Islamabad
# Shop3       Mavee Shah      Nokia  600$  Islamabad

# %%
# !cat olympics.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('olympics.csv',index_col=0,skiprows=1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# Afghanistan (AFG)             2               2
# Algeria (ALG)                 8              15
# Argentina (ARG)              28              70
# Armenia (ARM)                 9              12
# Australasia (ANZ) [ANZ]       5              12

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2] =='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2] =='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2] =='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
        if col[:1] =='№ ':
            df.rename(columns={col:'#'+col[1:]}, inplace=True)   
df.head()
# Out:
#                          № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)               0         2               2
# Algeria (ALG)                   2         8              15
# Argentina (ARG)                24        28              70
# Armenia (ARM)                   2         9              12
# Australasia (ANZ) [ANZ]         4         5              12

# %%
only_gold = df.where(df['Gold']>0)
only_gold.head()
# Out:
#                          № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
#                          Silver.2  Bronze.2  Combined total
# Afghanistan (AFG)             NaN       NaN             NaN
# Algeria (ALG)                 2.0       8.0            15.0
# Argentina (ARG)              24.0      28.0            70.0
# Armenia (ARM)                 2.0       9.0            12.0
# Australasia (ANZ) [ANZ]       4.0       5.0            12.0

# %%
print(only_gold['Gold'].count())
print(df['Gold'].count())
# Out:
# 100
# 147

# %%
only_gold = only_gold.dropna()
only_gold.head()
# Out:
#                            № Summer   Gold  Silver  Bronze  Total  № Winter  \
# Algeria (ALG)                  12.0    5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)                23.0   18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                   5.0    1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]         2.0    3.0     4.0     5.0   12.0       0.0
# Australia (AUS) [AUS] [Z]      25.0  139.0   152.0   177.0  468.0      18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  № Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0     15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0     41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0     11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0      2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0     43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# Algeria (ALG)                 5.0       2.0       8.0            15.0
# Argentina (ARG)              18.0      24.0      28.0            70.0
# Armenia (ARM)                 1.0       2.0       9.0            12.0
# Australasia (ANZ) [ANZ]       3.0       4.0       5.0            12.0
# Australia (AUS) [AUS] [Z]   144.0     155.0     181.0           480.0

# %% [markdown]
# without where clause

# %%
gold = df[df['Gold']>0]
gold.tail()
# Out:
#                         № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Venezuela (VEN)               17     2       2       8     12         4
# Yugoslavia (YUG) [YUG]        16    26      29      28     83        14
# Zimbabwe (ZIM) [ZIM]          12     3       4       1      8         1
# Mixed team (ZZX) [ZZX]         3     8       5       4     17         0
# Totals                        27  4809    4775    5130  14714        22
#
#                         Gold.1  Silver.1  Bronze.1  Total.1  № Games  Gold.2  \
# Venezuela (VEN)              0         0         0        0       21       2
# Yugoslavia (YUG) [YUG]       0         3         1        4       30      26
# Zimbabwe (ZIM) [ZIM]         0         0         0        0       13       3
# Mixed team (ZZX) [ZZX]       0         0         0        0        3       8
# Totals                     959       958       948     2865       49    5768
#
#                         Silver.2  Bronze.2  Combined total
# Venezuela (VEN)                2         8              12
# Yugoslavia (YUG) [YUG]        32        29              87
# Zimbabwe (ZIM) [ZIM]           4         1               8
# Mixed team (ZZX) [ZZX]         5         4              17
# Totals                      5733      6078           17579

# %%
gold = df.drop('Totals')
print(len(df[(df['Gold']>0) | df['Gold.1']>0]))
gold.tail()
# Out:
# 101
#                                               № Summer  Gold  Silver  Bronze  \
# Yugoslavia (YUG) [YUG]                              16    26      29      28
# Independent Olympic Participants (IOP) [IOP]         1     0       1       2
# Zambia (ZAM) [ZAM]                                  12     0       1       1
# Zimbabwe (ZIM) [ZIM]                                12     3       4       1
# Mixed team (ZZX) [ZZX]                               3     8       5       4
#
#                                               Total  № Winter  Gold.1  \
# Yugoslavia (YUG) [YUG]                           83        14       0
# Independent Olympic Participants (IOP) [IOP]      3         0       0
# Zambia (ZAM) [ZAM]                                2         0       0
# Zimbabwe (ZIM) [ZIM]                              8         1       0
# Mixed team (ZZX) [ZZX]                           17         0       0
#
#                                               Silver.1  Bronze.1  Total.1  \
# Yugoslavia (YUG) [YUG]                               3         1        4
# Independent Olympic Participants (IOP) [IOP]         0         0        0
# Zambia (ZAM) [ZAM]                                   0         0        0
# Zimbabwe (ZIM) [ZIM]                                 0         0        0
# Mixed team (ZZX) [ZZX]                               0         0        0
#
#                                               № Games  Gold.2  Silver.2  \
# Yugoslavia (YUG) [YUG]                             30      26        32
# Independent Olympic Participants (IOP) [IOP]        1       0         1
# Zambia (ZAM) [ZAM]                                 12       0         1
# Zimbabwe (ZIM) [ZIM]                               13       3         4
# Mixed team (ZZX) [ZZX]                              3       8         5
#
#                                               Bronze.2  Combined total
# Yugoslavia (YUG) [YUG]                              29              87
# Independent Olympic Participants (IOP) [IOP]         2               3
# Zambia (ZAM) [ZAM]                                   1               2
# Zimbabwe (ZIM) [ZIM]                                 1               8
# Mixed team (ZZX) [ZZX]                               4              17

# %%
df['Gold'].max()
# Out:
# 4809

# %%
gold.head(3)
# Out:
#                    № Summer  Gold  Silver  Bronze  Total  № Winter  Gold.1  \
# Afghanistan (AFG)        13     0       0       2      2         0       0
# Algeria (ALG)            12     5       2       8     15         3       0
# Argentina (ARG)          23    18      24      28     70        18       0
#
#                    Silver.1  Bronze.1  Total.1  № Games  Gold.2  Silver.2  \
# Afghanistan (AFG)         0         0        0       13       0         0
# Algeria (ALG)             0         0        0       15       5         2
# Argentina (ARG)           0         0        0       41      18        24
#
#                    Bronze.2  Combined total
# Afghanistan (AFG)         2               2
# Algeria (ALG)             8              15
# Argentina (ARG)          28              70

# %%
diff = (gold['Gold']-gold['Gold.1'])
print(diff.idxmax())
# Out:
# United States (USA) [P] [Q] [R] [Z]

# %%
sum = (gold['Gold'] + gold['Gold.1'])

# %%
df.tail()
# Out:
#                                               № Summer  Gold  Silver  Bronze  \
# Independent Olympic Participants (IOP) [IOP]         1     0       1       2
# Zambia (ZAM) [ZAM]                                  12     0       1       1
# Zimbabwe (ZIM) [ZIM]                                12     3       4       1
# Mixed team (ZZX) [ZZX]                               3     8       5       4
# Totals                                              27  4809    4775    5130
#
#                                               Total  № Winter  Gold.1  \
# Independent Olympic Participants (IOP) [IOP]      3         0       0
# Zambia (ZAM) [ZAM]                                2         0       0
# Zimbabwe (ZIM) [ZIM]                              8         1       0
# Mixed team (ZZX) [ZZX]                           17         0       0
# Totals                                        14714        22     959
#
#                                               Silver.1  Bronze.1  Total.1  \
# Independent Olympic Participants (IOP) [IOP]         0         0        0
# Zambia (ZAM) [ZAM]                                   0         0        0
# Zimbabwe (ZIM) [ZIM]                                 0         0        0
# Mixed team (ZZX) [ZZX]                               0         0        0
# Totals                                             958       948     2865
#
#                                               № Games  Gold.2  Silver.2  \
# Independent Olympic Participants (IOP) [IOP]        1       0         1
# Zambia (ZAM) [ZAM]                                 12       0         1
# Zimbabwe (ZIM) [ZIM]                               13       3         4
# Mixed team (ZZX) [ZZX]                              3       8         5
# Totals                                             49    5768      5733
#
#                                               Bronze.2  Combined total
# Independent Olympic Participants (IOP) [IOP]         2               3
# Zambia (ZAM) [ZAM]                                   1               2
# Zimbabwe (ZIM) [ZIM]                                 1               8
# Mixed team (ZZX) [ZZX]                               4              17
# Totals                                            6078           17579

# %%
avg_sum = (df[(df['Gold']>0) & df['Gold.1']>0])
avg_sum
# Out:
#                             № Summer  Gold  Silver  Bronze  Total  № Winter  \
# Australia (AUS) [AUS] [Z]         25   139     152     177    468        18
# Austria (AUT)                     26    18      33      35     86        22
# Belgium (BEL)                     25    37      52      53    142        20
# Bulgaria (BUL) [H]                19    51      85      78    214        19
# Czech Republic (CZE) [CZE]         5    14      15      15     44         6
# France (FRA) [O] [P] [Z]          27   202     223     246    671        22
# East Germany (GDR) [GDR]           5   153     129     127    409         6
# West Germany (FRG) [FRG]           5    56      67      81    204         6
# Italy (ITA) [M] [S]               26   198     166     185    549        22
# Kazakhstan (KAZ)                   5    16      17      19     52         6
# Netherlands (NED) [Z]             25    77      85     104    266        20
# Russia (RUS) [RUS]                 5   132     121     142    395         6
# Unified Team (EUN) [EUN]           1    45      38      29    112         1
# Spain (ESP) [Z]                   22    37      59      35    131        19
# Uzbekistan (UZB)                   5     5       5      10     20         6
# Totals                            27  4809    4775    5130  14714        22
#
#                             Gold.1  Silver.1  Bronze.1  Total.1  № Games  \
# Australia (AUS) [AUS] [Z]        5         3         4       12       43
# Austria (AUT)                   59        78        81      218       48
# Belgium (BEL)                    1         1         3        5       45
# Bulgaria (BUL) [H]               1         2         3        6       38
# Czech Republic (CZE) [CZE]       7         9         8       24       11
# France (FRA) [O] [P] [Z]        31        31        47      109       49
# East Germany (GDR) [GDR]        39        36        35      110       11
# West Germany (FRG) [FRG]        11        15        13       39       11
# Italy (ITA) [M] [S]             37        34        43      114       48
# Kazakhstan (KAZ)                 1         3         3        7       11
# Netherlands (NED) [Z]           37        38        35      110       45
# Russia (RUS) [RUS]              49        40        35      124       11
# Unified Team (EUN) [EUN]         9         6         8       23        2
# Spain (ESP) [Z]                  1         0         1        2       41
# Uzbekistan (UZB)                 1         0         0        1       11
# Totals                         959       958       948     2865       49
#
#                             Gold.2  Silver.2  Bronze.2  Combined total
# Australia (AUS) [AUS] [Z]      144       155       181             480
# Austria (AUT)                   77       111       116             304
# Belgium (BEL)                   38        53        56             147
# Bulgaria (BUL) [H]              52        87        81             220
# Czech Republic (CZE) [CZE]      21        24        23              68
# France (FRA) [O] [P] [Z]       233       254       293             780
# East Germany (GDR) [GDR]       192       165       162             519
# West Germany (FRG) [FRG]        67        82        94             243
# Italy (ITA) [M] [S]            235       200       228             663
# Kazakhstan (KAZ)                17        20        22              59
# Netherlands (NED) [Z]          114       123       139             376
# Russia (RUS) [RUS]             181       161       177             519
# Unified Team (EUN) [EUN]        54        44        37             135
# Spain (ESP) [Z]                 38        59        36             133
# Uzbekistan (UZB)                 6         5        10              21
# Totals                        5768      5733      6078           17579

# %%
diff = (avg_sum['Gold'] - avg_sum['Gold.1'])
print(diff.max())
sum = (avg_sum['Gold'] + avg_sum['Gold.1'])
print(sum)
avg = diff/sum
print(avg.max())
# Out:
# 3850
# Australia (AUS) [AUS] [Z]      144
# Austria (AUT)                   77
# Belgium (BEL)                   38
# Bulgaria (BUL) [H]              52
# Czech Republic (CZE) [CZE]      21
# France (FRA) [O] [P] [Z]       233
# East Germany (GDR) [GDR]       192
# West Germany (FRG) [FRG]        67
# Italy (ITA) [M] [S]            235
# Kazakhstan (KAZ)                17
# Netherlands (NED) [Z]          114
# Russia (RUS) [RUS]             181
# Unified Team (EUN) [EUN]        54
# Spain (ESP) [Z]                 38
# Uzbekistan (UZB)                 6
# Totals                        5768
# dtype: int64
# 0.9615384615384616

# %%
 df['Gold'].max(level = 0 )
# Out:
# Afghanistan (AFG)                                  0
# Algeria (ALG)                                      5
# Argentina (ARG)                                   18
# Armenia (ARM)                                      1
# Australasia (ANZ) [ANZ]                            3
# Australia (AUS) [AUS] [Z]                        139
# Austria (AUT)                                     18
# Azerbaijan (AZE)                                   6
# Bahamas (BAH)                                      5
# Bahrain (BRN)                                      0
# Barbados (BAR) [BAR]                               0
# Belarus (BLR)                                     12
# Belgium (BEL)                                     37
# Bermuda (BER)                                      0
# Bohemia (BOH) [BOH] [Z]                            0
# Botswana (BOT)                                     0
# Brazil (BRA)                                      23
# British West Indies (BWI) [BWI]                    0
# Bulgaria (BUL) [H]                                51
# Burundi (BDI)                                      1
# Cameroon (CMR)                                     3
# Canada (CAN)                                      59
# Chile (CHI) [I]                                    2
# China (CHN) [CHN]                                201
# Colombia (COL)                                     2
# Costa Rica (CRC)                                   1
# Ivory Coast (CIV) [CIV]                            0
# Croatia (CRO)                                      6
# Cuba (CUB) [Z]                                    72
# Cyprus (CYP)                                       0
#                                                 ...
# Sri Lanka (SRI) [SRI]                              0
# Sudan (SUD)                                        0
# Suriname (SUR) [E]                                 1
# Sweden (SWE) [Z]                                 143
# Switzerland (SUI)                                 47
# Syria (SYR)                                        1
# Chinese Taipei (TPE) [TPE] [TPE2]                  2
# Tajikistan (TJK)                                   0
# Tanzania (TAN) [TAN]                               0
# Thailand (THA)                                     7
# Togo (TOG)                                         0
# Tonga (TGA)                                        0
# Trinidad and Tobago (TRI) [TRI]                    2
# Tunisia (TUN)                                      3
# Turkey (TUR)                                      39
# Uganda (UGA)                                       2
# Ukraine (UKR)                                     33
# United Arab Emirates (UAE)                         1
# United States (USA) [P] [Q] [R] [Z]              976
# Uruguay (URU)                                      2
# Uzbekistan (UZB)                                   5
# Venezuela (VEN)                                    2
# Vietnam (VIE)                                      0
# Virgin Islands (ISV)                               0
# Yugoslavia (YUG) [YUG]                            26
# Independent Olympic Participants (IOP) [IOP]       0
# Zambia (ZAM) [ZAM]                                 0
# Zimbabwe (ZIM) [ZIM]                               3
# Mixed team (ZZX) [ZZX]                             8
# Totals                                          4809
# Name: Gold, Length: 147, dtype: int64

# %%
df.columns
# Out:
# Index(['№ Summer', 'Gold', 'Silver', 'Bronze', 'Total', '№ Winter', 'Gold.1',
#        'Silver.1', 'Bronze.1', 'Total.1', '№ Games', 'Gold.2', 'Silver.2',
#        'Bronze.2', 'Combined total'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['Afghanistan (AFG)', 'Algeria (ALG)', 'Argentina (ARG)',
#        'Armenia (ARM)', 'Australasia (ANZ) [ANZ]', 'Australia (AUS) [AUS] [Z]',
#        'Austria (AUT)', 'Azerbaijan (AZE)', 'Bahamas (BAH)', 'Bahrain (BRN)',
#        ...
#        'Uzbekistan (UZB)', 'Venezuela (VEN)', 'Vietnam (VIE)',
#        'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]',
#        'Independent Olympic Participants (IOP) [IOP]', 'Zambia (ZAM) [ZAM]',
#        'Zimbabwe (ZIM) [ZIM]', 'Mixed team (ZZX) [ZZX]', 'Totals'],
#       dtype='object', length=147)

# %%
df['Gold'].max(level = Index )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-ba31ffdd9352> in <module>
# ----> 1 df['Gold'].max(level = Index )
#
# NameError: name 'Index' is not defined

# %%
df.index.names = ['Country']

# %%
m = df['Gold']
m.max(level = 'Country' )
